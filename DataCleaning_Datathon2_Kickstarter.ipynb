# %% [markdown]
# # Data uploading & inspection

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# List the contents of your Drive folder to verify the path
data_folder = '/content/drive/MyDrive/Datathons_Data/'
os.listdir(data_folder)
# Out:
# ['london_listings.csv',
#  'bangkok_listings.csv',
#  'vancouver_listings.csv',
#  'cleaned_bangkok_listings.csv',
#  'cleaned_vancouver_listings.csv',
#  'cleaned_london_listings.csv',
#  'Kickstarter001.csv',
#  'Kickstarter002.csv',
#  'Kickstarter.csv',
#  'Kickstarter006.csv',
#  'Kickstarter004.csv',
#  'Kickstarter003.csv',
#  'Kickstarter005.csv']

# %%
# Import pandas
import pandas as pd

# Define the path to your files
data_path = '/content/drive/MyDrive/Datathons_Data/'

# Load the CSV files
kickstarter_df = pd.read_csv(data_path + 'Kickstarter.csv')
kickstarter001_df = pd.read_csv(data_path + 'Kickstarter001.csv')
kickstarter002_df = pd.read_csv(data_path + 'Kickstarter002.csv')
kickstarter003_df = pd.read_csv(data_path + 'Kickstarter003.csv')
kickstarter004_df = pd.read_csv(data_path + 'Kickstarter004.csv')
kickstarter005_df = pd.read_csv(data_path + 'Kickstarter005.csv')
kickstarter006_df = pd.read_csv(data_path + 'Kickstarter006.csv')

# Inspect the data
kickstarter_df.head()
# Out:
#    backers_count                                              blurb  \
# 0            157  The world's easiest and fastest-fitting winter...
# 1             19  Lil' Dog Chains fitted stainless steel dog col...
# 2            162  Tiny reflective decals and strips of tape just...
# 3             32  Living hidden in a house among a forest, the d...
# 4             31  Hume is a character-driven short film, directe...
#
#                                             category  \
# 0  {"id":268,"name":"Pet Fashion","analytics_name...
# 1  {"id":268,"name":"Pet Fashion","analytics_name...
# 2  {"id":268,"name":"Pet Fashion","analytics_name...
# 3  {"id":32,"name":"Shorts","analytics_name":"Sho...
# 4  {"id":32,"name":"Shorts","analytics_name":"Sho...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                   14707.0      CA                   Canada  1481586904
# 1                    4291.0      CA                   Canada  1474675676
# ...

# %%
#inspect data
kickstarter001_df.head()
# Out:
#    backers_count                                              blurb  \
# 0              0  This event will be free to the public with app...
# 1             33  A Thanksgiving film where a disjointed family ...
# 2             59  An album of 10 original Americana songs about ...
# 3            372  An intimate film about four women who find uni...
# 4              7  Super Strong Buff Resin Figures Produced as a ...
#
#                                             category  \
# 0  {"id":318,"name":"Faith","analytics_name":"Fai...
# 1  {"id":31,"name":"Narrative Film","analytics_na...
# 2  {"id":318,"name":"Faith","analytics_name":"Fai...
# 3  {"id":31,"name":"Narrative Film","analytics_na...
# 4  {"id":25,"name":"Sculpture","analytics_name":"...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                       0.0      US        the United States  1446199121
# 1                    3387.0      US        the United States  1487724337
# ...

# %%
#inspect data
kickstarter002_df.head()
# Out:
#    backers_count                                              blurb  \
# 0              3  Help us to perfect our KBS (Kampin' Breakfast ...
# 1              5  Firehouse Coffee is a small, artisan roastery ...
# 2              4  Flaky, butter croissants reinvented with nuanc...
# 3             19  Ma jeune marque a pour priorité de promouvoir ...
# 4            156  A collection of original and traditional fiddl...
#
#                                             category  \
# 0  {"id":313,"name":"Small Batch","analytics_name...
# 1  {"id":313,"name":"Small Batch","analytics_name...
# 2  {"id":313,"name":"Small Batch","analytics_name...
# 3  {"id":276,"name":"Fine Art","analytics_name":"...
# 4  {"id":37,"name":"Country & Folk","analytics_na...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                      41.0      US        the United States  1478187572
# 1                     176.0      US        the United States  1478042350
# ...

# %%
#inspect data
kickstarter003_df.head()
# Out:
#    backers_count                                              blurb  \
# 0              5  Upskill and Stay Ahead: Prepare for the Genera...
# 1            709  A gritty post/post-apocalyptic graphic novel t...
# 2              2  Funding the production of the screenplay NIGHT...
# 3              2  No puedes seducir a otra persona si antes no h...
# 4             86  This Album is the sum total of the last two ye...
#
#                                             category  \
# 0  {"id":51,"name":"Software","analytics_name":"S...
# 1  {"id":252,"name":"Graphic Novels","analytics_n...
# 2  {"id":292,"name":"Comedy","analytics_name":"Co...
# 3  {"id":292,"name":"Comedy","analytics_name":"Co...
# 4  {"id":42,"name":"Pop","analytics_name":"Pop","...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                     393.0      CA                   Canada  1689348889
# 1                   41194.0      US        the United States  1710608211
# ...

# %%
#inspect data
kickstarter004_df.head()
# Out:
#    backers_count                                              blurb  \
# 0             56  To fund the creation and vinyl production of J...
# 1             17  A webseries that showcases live, independent a...
# 2              2  This is my book, CARBON COPY, a dream that is ...
# 3              0  Help Planet Arbitrary become an entertainment ...
# 4              5  It's an art project in support of women's prot...
#
#                                             category  \
# 0  {"id":44,"name":"World Music","analytics_name"...
# 1  {"id":239,"name":"Radio & Podcasts","analytics...
# 2  {"id":54,"name":"Mixed Media","analytics_name"...
# 3  {"id":239,"name":"Radio & Podcasts","analytics...
# 4  {"id":54,"name":"Mixed Media","analytics_name"...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                    4020.0      GB       the United Kingdom  1678716724
# 1                    1186.0      US        the United States  1366652691
# ...

# %%
#inspect data
kickstarter005_df.head()
# Out:
#    backers_count                                              blurb  \
# 0             90  A spiritual-sci-fi-dramedy from award winning ...
# 1             46  Inspiré d'une tradition japonaise, cet album j...
# 2              4  Wood sculptures inspired by the natural forms ...
# 3              0  This project is to design and build a computer...
# 4              0  We want to unite America's leaders together th...
#
#                                             category  \
# 0  {"id":31,"name":"Narrative Film","analytics_na...
# 1  {"id":46,"name":"Children's Books","analytics_...
# 2  {"id":25,"name":"Sculpture","analytics_name":"...
# 3  {"id":25,"name":"Sculpture","analytics_name":"...
# 4  {"id":25,"name":"Sculpture","analytics_name":"...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                   12031.0      US        the United States  1539900239
# 1                    2968.0      FR                   France  1717790973
# ...

# %%
#inspect data
kickstarter006_df.head()
# Out:
#    backers_count                                              blurb  \
# 0             13                    How to create amazing pictures!
# 1             62  A bunch of leather goodies that are made with ...
# 2            117  A set of original washi tape designs, art by M...
# 3             54  Using vacant storefront windows and projected ...
# 4             54  Producing and selling the YOUNG HERO summer 20...
#
#                                             category  \
# 0  {"id":280,"name":"Photobooks","analytics_name"...
# 1  {"id":345,"name":"DIY","analytics_name":"DIY",...
# 2  {"id":353,"name":"Stationery","analytics_name"...
# 3  {"id":53,"name":"Public Art","analytics_name":...
# 4  {"id":266,"name":"Footwear","analytics_name":"...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                     278.0      MX                   Mexico  1629757580
# 1                    5340.0      US        the United States  1574216818
# ...

# %% [markdown]
# # Data expection

# %%
#check for missing values and data types in the Kickstarter dataset
print("Kickstarter Dataset Information:")
print(kickstarter_df.info())
print("\nMissing Values in Kickstarter Dataset:")
print(kickstarter_df.isnull().sum())

#check for missing values and data types in the Kickstarter001 dataset
print("Kickstarter001 Dataset Information:")
print(kickstarter001_df.info())
print("\nMissing Values in Kickstarter001 Dataset:")
print(kickstarter001_df.isnull().sum())

#check for missing values and data types in the Kickstarter002 dataset
print("Kickstarter002 Dataset Information:")
print(kickstarter002_df.info())
print("\nMissing Values in Kickstarter002 Dataset:")
print(kickstarter002_df.isnull().sum())

#check for missing values and data types in the Kickstarter003 dataset
print("Kickstarter003 Dataset Information:")
print(kickstarter003_df.info())
print("\nMissing Values in Kickstarter003 Dataset:")
print(kickstarter003_df.isnull().sum())

#check for missing values and data types in the Kickstarter004 dataset
print("Kickstarter004 Dataset Information:")
print(kickstarter004_df.info())
print("\nMissing Values in Kickstarter004 Dataset:")
print(kickstarter004_df.isnull().sum())

#check for missing values and data types in the Kickstarter005 dataset
print("Kickstarter005 Dataset Information:")
print(kickstarter005_df.info())
print("\nMissing Values in Kickstarter005 Dataset:")
print(kickstarter005_df.isnull().sum())

#check for missing values and data types in the Kickstarter006 dataset
print("Kickstarter006 Dataset Information:")
print(kickstarter006_df.info())
print("\nMissing Values in Kickstarter006 Dataset:")
print(kickstarter006_df.isnull().sum())
# Out:
# Kickstarter Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3310 entries, 0 to 3309
# Data columns (total 42 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   backers_count                       3310 non-null   int64
#  1   blurb                               3310 non-null   object
#  2   category                            3310 non-null   object
#  3   converted_pledged_amount            3183 non-null   float64
#  4   country                             3310 non-null   object
#  5   country_displayable_name            3310 non-null   object
#  6   created_at                          3310 non-null   int64
#  7   creator                             3310 non-null   object
#  8   currency                            3310 non-null   object
#  9   currency_symbol                     3310 non-null   object
# ...

# %%
# Have a single dataframe
kickstarter_dfs = [kickstarter_df, kickstarter001_df, kickstarter002_df, kickstarter003_df, kickstarter004_df, kickstarter005_df, kickstarter006_df]

#concatenate all dataframes into one
kickstarter_data = pd.concat(kickstarter_dfs, ignore_index=True)

#remove duplicates based on "id" column
kickstarter_data.drop_duplicates(subset='id', keep='first', inplace=True)

#check the shape of the dataframe after merging
print("Shape of the merged dataframe:", kickstarter_data.shape)
# Out:
# Shape of the merged dataframe: (22728, 42)

# %%
#handle missing values
missing_values = kickstarter_data.isnull().sum()
print("Missing Values in Each Column:")
print(missing_values)
# Out:
# Missing Values in Each Column:
# CategoryV1                     0
# CreatorV1                      0
# LocationV1                     0
# State                          0
# backers_count                  0
# blurb                          0
# converted_pledged_amount       0
# country                        0
# country_displayable_name       0
# created_at                     0
# currency                       0
# currency_symbol                0
# currency_trailing_code         0
# current_currency               0
# deadline                       0
# disable_communication          0
# fx_rate                        0
# goal                           0
# id                             0
# is_disliked                    0
# is_launched                    0
# is_liked                       0
# is_starrable                   0
# launched_at                    0
# name                           0
# percent_funded              1024
# photo                          0
# ...

# %% [markdown]
# #data cleaning columns

# %%
# Fill missing values by directly assigning to each column
kickstarter_data['converted_pledged_amount'] = kickstarter_data['converted_pledged_amount'].fillna(0)
kickstarter_data['usd_pledged'] = kickstarter_data['usd_pledged'].fillna(0)
kickstarter_data['usd_exchange_rate'] = kickstarter_data['usd_exchange_rate'].fillna(0)
kickstarter_data['blurb'] = kickstarter_data['blurb'].fillna('')
kickstarter_data['usd_type'] = kickstarter_data['usd_type'].fillna('unknown')

# Drop columns with high missing values directly
kickstarter_data = kickstarter_data.drop(columns=['is_in_post_campaign_pledging_phase','video'])

# Verify if there are still any missing values
print("Remaining missing values:\n", kickstarter_data.isnull().sum())
# Out:
# Remaining missing values:
#  backers_count                0
# blurb                        0
# category                     0
# converted_pledged_amount     0
# country                      0
# country_displayable_name     0
# created_at                   0
# creator                      0
# currency                     0
# currency_symbol              0
# currency_trailing_code       0
# current_currency             0
# deadline                     0
# disable_communication        0
# fx_rate                      0
# goal                         0
# id                           0
# is_disliked                  0
# is_launched                  0
# is_liked                     0
# is_starrable                 0
# launched_at                  0
# location                    22
# name                         0
# percent_funded               0
# photo                        0
# pledged                      0
# prelaunch_activated          0
# profile                      0
# ...

# %%
# Identify rows where JSON decoding fails for each column
for col in ['category', 'creator', 'location', 'profile']:
    invalid_json_rows = kickstarter_data[kickstarter_data[col].apply(lambda x: not isinstance(x, str) or not x.startswith('{'))]
    print(f"Invalid JSON rows in {col} column:\n", invalid_json_rows[[col]].head())
# Out:
# Invalid JSON rows in category column:
#  Empty DataFrame
# Columns: [category]
# Index: []
# Invalid JSON rows in creator column:
#  Empty DataFrame
# Columns: [creator]
# Index: []
# Invalid JSON rows in location column:
#       location
# 515       NaN
# 1465      NaN
# 2023      NaN
# 2036      NaN
# 5406      NaN
# Invalid JSON rows in profile column:
#  Empty DataFrame
# Columns: [profile]
# Index: []

# %% [markdown]
# #Reformating the category, creator, location, and profile columns.

# %%
import json

# Function to extract and create the new columns with error handling, including NaN check for 'location'
def extract_json_fields(df):
    # Extract from 'category'
    def parse_category(x):
        try:
            json_data = json.loads(x)
            return json_data['analytics_name'] if json_data['name'] != json_data['analytics_name'] else json_data['name']
        except (json.JSONDecodeError, TypeError):
            return None

    # Extract from 'creator'
    def parse_creator(x):
        try:
            return json.loads(x)['name']
        except (json.JSONDecodeError, TypeError):
            return None

    # Extract from 'location' with NaN check
    def parse_location(x):
        if pd.isna(x):  # If the value is NaN, return None directly
            return None
        try:
            return json.loads(x)['name']
        except (json.JSONDecodeError, TypeError):
            return None

    # Extract from 'profile'
    def parse_profile(x):
        try:
            return json.loads(x)['state']
        except (json.JSONDecodeError, TypeError):
            return None

    # Apply the parsing functions
    df['CategoryV1'] = df['category'].apply(parse_category)
    df['CreatorV1'] = df['creator'].apply(parse_creator)
    df['LocationV1'] = df['location'].apply(parse_location)
    df['State'] = df['profile'].apply(parse_profile)

    return df

# Apply the function to extract fields
kickstarter_data = extract_json_fields(kickstarter_data)

# Reorder columns as specified
columns_order = ['CategoryV1', 'CreatorV1', 'LocationV1', 'State'] + \
                [col for col in kickstarter_data.columns if col not in ['CategoryV1', 'CreatorV1', 'LocationV1', 'State', 'category', 'creator', 'location', 'profile']] + \
                ['category', 'creator', 'location', 'profile']

kickstarter_data = kickstarter_data[columns_order]

# Display the updated DataFrame to confirm changes
kickstarter_data.head()
# Out:
#     CategoryV1                  CreatorV1 LocationV1     State  backers_count  \
# 0  Pet Fashion             World of Angus    Toronto      None            157
# 1  Pet Fashion           Miguel del Moral   Montreal  inactive             19
# 2  Pet Fashion                 Elton King   Portland  inactive            162
# 3       Shorts  Alfredo Hernandez Alvarez   Veracruz  inactive             32
# 4       Shorts              Octavia Grove     London  inactive             31
#
#                                                blurb  \
# 0  The world's easiest and fastest-fitting winter...
# 1  Lil' Dog Chains fitted stainless steel dog col...
# 2  Tiny reflective decals and strips of tape just...
# 3  Living hidden in a house among a forest, the d...
# 4  Hume is a character-driven short film, directe...
#
#    converted_pledged_amount country country_displayable_name  created_at  ...  \
# 0                   14707.0      CA                   Canada  1481586904  ...
# ...

# %%
# Verify if there are still any missing values
print("Remaining missing values:\n", kickstarter_data.isnull().sum())
# Out:
# Remaining missing values:
#  CategoryV1                    0
# CreatorV1                    56
# LocationV1                   22
# State                       357
# backers_count                 0
# blurb                         0
# converted_pledged_amount      0
# country                       0
# country_displayable_name      0
# created_at                    0
# currency                      0
# currency_symbol               0
# currency_trailing_code        0
# current_currency              0
# deadline                      0
# disable_communication         0
# fx_rate                       0
# goal                          0
# id                            0
# is_disliked                   0
# is_launched                   0
# is_liked                      0
# is_starrable                  0
# launched_at                   0
# name                          0
# percent_funded                0
# photo                         0
# pledged                       0
# ...

# %%
# Drop rows with missing values in 'CreatorV1', 'LocationV1', 'State', or 'location'
kickstarter_data = kickstarter_data.dropna(subset=['CreatorV1', 'LocationV1', 'State','location'])

# Verify no missing values remain in these columns
print("Remaining missing values:\n", kickstarter_data[['CreatorV1', 'LocationV1', 'State', 'location']].isnull().sum())
# Out:
# Remaining missing values:
#  CreatorV1     0
# LocationV1    0
# State         0
# location      0
# dtype: int64

# %% [markdown]
# # Calculations for Visualization: Distance to Goal , Percentage Funded, and Date Conversions

# %%
import pandas as pd
import json

# Assuming `kickstarter_data` is the DataFrame with all the necessary columns loaded

# Step 1: Calculate surplus_funding and distance_to_goal
kickstarter_data['surplus_funding'] = kickstarter_data.apply(
    lambda row: max(row['pledged'] - row['goal'], 0), axis=1
)

kickstarter_data['distance_to_goal'] = kickstarter_data.apply(
    lambda row: max(row['goal'] - row['pledged'], 0), axis=1
)

# Step 2: Add funding_status to indicate whether the goal was met or exceeded
kickstarter_data['funding_status'] = kickstarter_data['pledged'] >= kickstarter_data['goal']

# Step 3: Recalculate percentage funded for consistency
kickstarter_data['percent_funded'] = (kickstarter_data['pledged'] / kickstarter_data['goal']) * 100

# step 4: Ensure the columns are in integer format before converting to datetime
kickstarter_data['created_at'] = pd.to_datetime(kickstarter_data['created_at'].astype(float), unit='s', errors='coerce')
kickstarter_data['launched_at'] = pd.to_datetime(kickstarter_data['launched_at'].astype(float), unit='s', errors='coerce')
kickstarter_data['deadline'] = pd.to_datetime(kickstarter_data['deadline'].astype(float), unit='s', errors='coerce')
kickstarter_data['state_changed_at'] = pd.to_datetime(kickstarter_data['state_changed_at'].astype(float), unit='s', errors='coerce')

# Strip time component, keeping only the date
kickstarter_data['created_at'] = kickstarter_data['created_at'].dt.date
kickstarter_data['launched_at'] = kickstarter_data['launched_at'].dt.date
kickstarter_data['deadline'] = kickstarter_data['deadline'].dt.date
kickstarter_data['state_changed_at'] = kickstarter_data['state_changed_at'].dt.date

# Display the first few rows to confirm changes
kickstarter_data[['surplus_funding', 'distance_to_goal', 'percent_funded', 'created_at', 'launched_at', 'deadline', 'state_changed_at']].head()
# Out:
#    surplus_funding  distance_to_goal  percent_funded  created_at launched_at  \
# 1           1802.0               0.0      145.050000  2016-09-24  2016-11-03
# 2           1219.0               0.0      160.950000  2016-04-16  2016-04-26
# 3           4050.0               0.0      116.200000  2018-01-24  2018-02-23
# 4              0.0               0.0      100.000000  2018-02-18  2018-02-22
# 5           5380.0               0.0      171.733333  2018-01-31  2018-02-16
#
#      deadline state_changed_at
# 1  2016-11-27       2016-11-27
# 2  2016-06-07       2016-06-07
# 3  2018-03-25       2018-03-25
# 4  2018-03-24       2018-03-24
# 5  2018-03-17       2018-03-17

# %% [markdown]
# # Removing unecesary columns to avoid a huge file

# %%
print("kikckstart Dataset Information:")
print(kickstarter_data.info())
# Out:
# kikckstart Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22296 entries, 1 to 22996
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CategoryV1                22296 non-null  object
#  1   CreatorV1                 22296 non-null  object
#  2   LocationV1                22296 non-null  object
#  3   State                     22296 non-null  object
#  4   backers_count             22296 non-null  int64
#  5   blurb                     22296 non-null  object
#  6   converted_pledged_amount  22296 non-null  float64
#  7   country                   22296 non-null  object
#  8   country_displayable_name  22296 non-null  object
#  9   created_at                22296 non-null  object
#  10  currency                  22296 non-null  object
#  11  currency_symbol           22296 non-null  object
#  12  currency_trailing_code    22296 non-null  bool
# ...

# %%
# Extract ParentCategoryV1 from category JSON
kickstarter_data['ParentCategoryV1'] = kickstarter_data['category'].apply(lambda x: json.loads(x).get('parent_name') if pd.notnull(x) else None)

# Drop columns that are non-essential for analysis
columns_to_drop = [
    'category', 'currency_symbol', 'currency_trailing_code', 'disable_communication',
    'is_disliked', 'is_in_post_campaign_pledging_phase', 'is_launched', 'is_liked',
    'is_starrable', 'location', 'photo', 'prelaunch_activated', 'profile', 'slug',
    'source_url', 'urls', 'video', 'static_usd_rate', 'usd_exchange_rate'
]

# Drop specified columns
kickstarter_data = kickstarter_data.drop(columns=columns_to_drop, errors='ignore')

# Display remaining columns to confirm
print("Remaining columns after cleanup:", kickstarter_data.columns.tolist())
# Out:
# Remaining columns after cleanup: ['CategoryV1', 'CreatorV1', 'LocationV1', 'State', 'backers_count', 'blurb', 'converted_pledged_amount', 'country', 'country_displayable_name', 'created_at', 'currency', 'current_currency', 'deadline', 'fx_rate', 'goal', 'id', 'launched_at', 'name', 'percent_funded', 'pledged', 'spotlight', 'staff_pick', 'state', 'state_changed_at', 'usd_pledged', 'usd_type', 'creator', 'surplus_funding', 'distance_to_goal', 'funding_status', 'ParentCategoryV1']
# Reduced data saved at: /content/drive/MyDrive/Datathons_Data/reduced_kickstarter_data.csv

# %% [markdown]
# # Exporting files

# %%
# Export the cleaned datasets to CSV
cleaned_data_path = '/content/drive/MyDrive/Datathons_Data/cleaned_kickstarter_data.csv'
kickstarter_data.to_csv(cleaned_data_path, index=False)
